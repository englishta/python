# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.arange(-5, 5, 0.1)
y = 10*(x**3) + 100*np.random.randn(len(x))
plt.plot(x, y, '.')

# %%
model2 = linear_model.LinearRegression()
X = np.c_[x**3]
Y = np.c_[y]
model2.fit(X, Y)
print("Mean = {}".format(np.mean( (Y-model2.predict(X))**2 )**0.5))
print("r2_score = {}\n".format(r2_score(Y, model2.predict(X))))
# Out:
# Mean = 89.45065602793807
# r2_score = 0.9669600816578141

# %%
model2 = linear_model.LinearRegression()
X_ = np.c_[x, x**2, x**3]
Y_=np.c_[y]
model2.fit(X_, Y_)
print("Mean = {}".format(np.mean( (Y_-model2.predict(X_))**2 )**0.5))
print("r2_score = {}\n".format(r2_score(Y_, model2.predict(X_))))
# Out:
# Mean = 89.26965004741929
# r2_score = 0.9670936608242979

# %%
#iris_start

# %%
iris = datasets.load_iris()
X = iris.data
Y = iris.target

X_train = X[ np.arange(0, len(X), 2) ]
Y_train = Y[ np.arange(0, len(Y), 2) ]

X_test = X[ np.arange(1, len(X), 2) ]
Y_test = Y[ np.arange(1, len(Y), 2) ]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
ef = []
k_value = []
for k in range(1, 60):
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(X_train, Y_train)
    Y_predicted = model.predict(X_test)
    metrics.confusion_matrix(Y_test, Y_predicted)
    ef.append(metrics.accuracy_score(Y_test, Y_predicted))
    k_value.append(k)

# %%
import matplotlib.pyplot as plt
plt.plot(k_value, ef, 'r.-')

# %%
model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train, Y_train)
Y_predicted = model.predict(X_test)
print("5_version")
print("accuracy = {}\n".format(metrics.accuracy_score(Y_test, Y_predicted)))
metrics.confusion_matrix(Y_test, Y_predicted)
# Out:
# 5_version
# accuracy = 0.9866666666666667
# array([[25,  0,  0],
#        [ 0, 24,  1],
#        [ 0,  0, 25]])

# %%
model = KNeighborsClassifier(n_neighbors=10)
model.fit(X_train, Y_train)
Y_predicted = model.predict(X_test)
print("10_version")
print("accuracy = {}\n".format(metrics.accuracy_score(Y_test, Y_predicted)))
metrics.confusion_matrix(Y_test, Y_predicted)
# Out:
# 10_version
# accuracy = 0.92
# array([[25,  0,  0],
#        [ 0, 24,  1],
#        [ 0,  5, 20]])

# %%
model = KNeighborsClassifier(n_neighbors=30)
model.fit(X_train, Y_train)
Y_predicted = model.predict(X_test)
print("30_version")
print("accuracy = {}\n".format(metrics.accuracy_score(Y_test, Y_predicted)))
metrics.confusion_matrix(Y_test, Y_predicted)
# Out:
# 30_version
# accuracy = 0.8933333333333333
# array([[25,  0,  0],
#        [ 0, 24,  1],
#        [ 0,  7, 18]])

# %%
model = KNeighborsClassifier(n_neighbors=55)
model.fit(X_train, Y_train)
Y_predicted = model.predict(X_test)
print("55_version")
print("accuracy = {}\n".format(metrics.accuracy_score(Y_test, Y_predicted)))
metrics.confusion_matrix(Y_test, Y_predicted)
# Out:
# 55_version
# accuracy = 0.6666666666666666
# array([[25,  0,  0],
#        [ 0, 25,  0],
#        [ 0, 25,  0]])

# %%
model = KNeighborsClassifier(n_neighbors=1)
model.fit(X_train, Y_train)
Y_predicted = model.predict(X_test)
print("1_version")
print("accuracy = {}\n".format(metrics.accuracy_score(Y_test, Y_predicted)))
metrics.confusion_matrix(Y_test, Y_predicted)
# Out:
# 1_version
# accuracy = 0.96
# array([[25,  0,  0],
#        [ 0, 24,  1],
#        [ 0,  2, 23]])

# %%
model = KNeighborsClassifier(n_neighbors=4)
model.fit(X_train, Y_train)
Y_predicted = model.predict(X_test)
print("55_version")
print("accuracy = {}\n".format(metrics.accuracy_score(Y_test, Y_predicted)))
metrics.confusion_matrix(Y_test, Y_predicted)
# Out:
# 55_version
# accuracy = 0.9466666666666667
# array([[25,  0,  0],
#        [ 0, 24,  1],
#        [ 0,  3, 22]])
