# %% [markdown]
# # 課題

# %% [raw]
# 名前:student2  学籍番号:2

# %% [markdown]
# ## 問1
# `print()` を用いて「Hello World!」と出力

# %%
# 解答欄
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## 問2
# $10!$ を計算し，結果を`print()`で出力

# %%
# 解答欄
def factorial(n):
    if n == 1:
        return 1
    return n * factorial(n - 1)
print(factorial(10))
# Out:
# 362880

# %% [markdown]
# ## 評価
# ### 点数

# %%
採点結果: 3点

# %% [markdown]
# ### コメント
